# %% [markdown]
# # ETL SPOTIFY DATA
#
# En este notebook se hace una ETL de los datos de spotify con obejtivo de crear un modelo de datos optimo en PowerBi. Para su posterior carga y desarrollo del dashboard, las tablas deben mantener un orden. Que todos los datos esten en una unica tabla no es una buena practica. Para optimizar el modelo se crearan las tablas necesarias (tablas maestro, tablas fact y tablas de dimensiones...) y se creara un modelo de copo de nieve o estrella en powerbi.

# %%
#Librerias
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import math
from datetime import datetime as dt, timedelta
import warnings
from IPython.display import Image, display
import os

#Ignoramos todos los warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 1. Carga de datos

# %%
path_base='/Users/Garazi/Desktop/SPOTIFY/'
path='DATA/ORIGEN/'
archivo_1='Streaming_History_Audio_2016_2019_0.json'
archivo_2='Streaming_History_Audio_2019_2020_1.json'
archivo_3='Streaming_History_Audio_2020_2021_2.json'
archivo_4='Streaming_History_Audio_2021_2023_3.json'
archivo_5='Streaming_History_Audio_2023_2024_4.json'


df_1619=pd.read_json(path_base+path+archivo_1)
df_1920=pd.read_json(path_base+path+archivo_2)
df_2021=pd.read_json(path_base+path+archivo_3)
df_2123=pd.read_json(path_base+path+archivo_4)
df_2324=pd.read_json(path_base+path+archivo_5)

# %%
#Se juntas los datos de todos los años en un único df y eliminamos los duplicados que hemos generado
df=pd.concat([df_1619,df_1920,df_2021,df_2123,df_2324])
df.drop_duplicates(inplace=True)

#La columna ts (fecha) es de tipo object, la ponemos como datetime
df['ts'] = pd.to_datetime(df['ts'])

#Se seleccionan y se renombran las columnas
df=df[['ts','ms_played','master_metadata_track_name', 'master_metadata_album_artist_name','master_metadata_album_album_name', 'episode_name','episode_show_name', 'reason_start','reason_end', 'shuffle', 'skipped']]

df.rename(columns=({'ts':'fecha','ms_played':'milisegundos',
                   'master_metadata_track_name':'Nombre_pista',
                   'master_metadata_album_artist_name':'Nombre_artista',
                   'master_metadata_album_album_name':'Nombre_album',
                   'episode_name':'Nombre_episodio',
                   'episode_show_name':'Nombre_show_episodio',
                   'reason_start':'razon_comienzo',
                   'reason_end':'razon_fin',
                   'shuffle':'aleatorio',
                   'skipped':'saltado'}), inplace=True)

# %% [markdown]
# Partiendo del df general creamos dos dfs diferentes: uno con datos de podcasts/epidodios (df_podcast), y otro con datos de canciones (df_music). Y eliminamos de cada df las columnas que no tienen que ver con su contenido (estas columnas aparecen rellenas con Nan/None).

# %%
df_podcast=df[df['Nombre_show_episodio'].notna()]
df_podcast.dropna(axis=1, how='all', inplace=True)
df_music=df[~df['Nombre_show_episodio'].notna()]
df_music.dropna(axis=1, how='all', inplace=True)

# %% [markdown]
# ## 2. Modelo de datos

# %% [markdown]
# Para saber que tablas van a ser necesarias, he creado una primera versión de modelo de datos. En la siguiente imagen se muestran las tablas. Es una primera versión, en Power Bi se desarrollara el modelo de datos correctamente.

# %%
path='ETL_EDA/modelo_datos.png'
display(Image(filename=path_base+path))

# %% [markdown]
# ### 2.1 Tablas generales
#
# Teniendo en cuenta las ventajas y la capacidad de Power Bi para tratar con tablas Calendar, la tabla de fechas la crearemos en el propio Power Bi. Por otro lado, para obtener las tablas comunes de Musica y de Podcast (RazonComienzo, RazonFin) partiremos de la taba general.
#
# pd: he ido creando las tablas una a una. Pendiente crear una funcion general que automatice este proceso, hacerlo de este modo cuando la cantidad de tablas es mayor es muy pesado e ineficiente.
#
# #### 2.1.1 RazonComienzo

# %%
df_comienzo=df['razon_comienzo'].drop_duplicates().reset_index(drop=True).to_frame()
df_comienzo.insert(0, 'idnt_comienzo', df_comienzo.index + 1)
df_comienzo
# Out:
#    idnt_comienzo razon_comienzo
# 0              1        appload
# 1              2      trackdone
# 2              3         fwdbtn
# 3              4       clickrow
# 4              5     trackerror
# 5              6         remote
# 6              7        backbtn
# 7              8        playbtn
# 8              9        unknown

# %% [markdown]
# #### 2.1.2 RazonFin

# %%
df_fin=df['razon_fin'].drop_duplicates().reset_index(drop=True).to_frame()
df_fin.insert(0, 'idnt_fin', df_fin.index + 1)
df_fin
# Out:
#     idnt_fin                     razon_fin
# 0          1                     trackdone
# 1          2                       endplay
# 2          3                       appload
# 3          4                        fwdbtn
# 4          5  unexpected-exit-while-paused
# 5          6               unexpected-exit
# 6          7                        logout
# 7          8                        remote
# 8          9                       backbtn
# 9         10                    trackerror
# 10        11                       unknown

# %% [markdown]
# ### 2.1 Tablas de Música
#
# #### 2.1.1 Tablas de Dimensiones
#
# ##### 2.1.1.1 Artistas

# %%
df_artistas=df_music['Nombre_artista'].drop_duplicates().reset_index(drop=True).to_frame()
df_artistas.insert(0, 'idnt_artista', df_artistas.index + 1)
df_artistas
# Out:
#       idnt_artista     Nombre_artista
# 0                1      Justin Bieber
# 1                2             Jack Ü
# 2                3            Melendi
# 3                4        Extremoduro
# 4                5  Fito y Fitipaldis
# ...            ...                ...
# 1994          1995        Salina Cruz
# 1995          1996            Florito
# 1996          1997       Joseph Nimoh
# 1997          1998            Yzalune
# 1998          1999  Emiliano Bruguera
#
# [1999 rows x 2 columns]

# %% [markdown]
# ##### 2.1.1.2 Albumes

# %%
df_album=df_music['Nombre_album'].drop_duplicates().reset_index(drop=True).to_frame()
df_album.insert(0, 'idnt_album', df_album.index + 1)
df_album
# Out:
#       idnt_album                         Nombre_album
# 0              1                              Purpose
# 1              2    Skrillex and Diplo present Jack Ü
# 2              3       Mientras No Cueste Más Trabajo
# 3              4              Sin Noticias De Holanda
# 4              5  Aún Más Curiosa La Cara De Tu Padre
# ...          ...                                  ...
# 5195        5196                       Easy Jazz Cafe
# 5196        5197                           Cookie Jar
# 5197        5198                             Lazyness
# 5198        5199                      Sleep All Night
# 5199        5200                          Ondas Delta
#
# [5200 rows x 2 columns]

# %% [markdown]
# ##### 2.1.1.3 Canciones

# %%
df_cancion=df_music[['Nombre_pista','Nombre_artista','Nombre_album']].drop_duplicates().reset_index(drop=True)

#Se introducen los identificadores únicos de los albumes y del artista, eliminando las descripciones.
df_cancion = df_cancion.merge(df_album[['idnt_album', 'Nombre_album']],how='left',on='Nombre_album')
df_cancion = df_cancion.merge(df_artistas[['idnt_artista', 'Nombre_artista']],how='left',on='Nombre_artista')
df_cancion=df_cancion[['Nombre_pista','idnt_album','idnt_artista']]
df_cancion.insert(0, 'idnt_pista', df_cancion.index + 1)
df_cancion
# Out:
#        idnt_pista                           Nombre_pista  idnt_album  \
# 0               1                                  Sorry           1
# 1               2                          Love Yourself           1
# 2               3                      What Do You Mean?           1
# 3               4   Where Are Ü Now (with Justin Bieber)           2
# 4               5                    El Tiempo Que Gasto           3
# ...           ...                                    ...         ...
# 11152       11153                      Soothing Twilight        5188
# 11153       11154                           Brewed Bliss        5188
# 11154       11155                        Sleep All Night        5199
# 11155       11156  Ondas Delta para Dormir Profundamente        5200
# 11156       11157             Ondas Delta para Relajarse        5200
#
#        idnt_artista
# 0                 1
# 1                 1
# 2                 1
# 3                 2
# 4                 3
# ...             ...
# 11152          1994
# 11153          1994
# 11154          1998
# 11155          1999
# 11156          1999
#
# [11157 rows x 4 columns]

# %% [markdown]
# #### 2.1.2 Tabla de Hechos
# ##### 2.1.2.1 Música

# %%
df_musica=df_music[['fecha','milisegundos','Nombre_pista','razon_comienzo','razon_fin','aleatorio','saltado']]

df_musica=df_musica.merge(df_cancion[['Nombre_pista','idnt_pista']],how='left',on='Nombre_pista')
df_musica=df_musica.merge(df_comienzo[['razon_comienzo','idnt_comienzo']],how='left',on='razon_comienzo')
df_musica=df_musica.merge(df_fin[['razon_fin','idnt_fin']],how='left',on='razon_fin')

df_musica=df_musica[['fecha','milisegundos','idnt_pista','idnt_comienzo','idnt_fin','aleatorio','saltado']]
df_musica.insert(0, 'idnt_music', df_musica.index + 1)
df_musica
# Out:
#         idnt_music                     fecha  milisegundos  idnt_pista  \
# 0                1 2016-02-09 13:44:41+00:00        333659           1
# 1                2 2016-02-09 13:48:02+00:00        200786           1
# 2                3 2016-02-09 13:51:23+00:00        200786           1
# 3                4 2016-02-09 13:54:44+00:00        200786           1
# 4                5 2016-02-09 13:58:41+00:00        200786           1
# ...            ...                       ...           ...         ...
# 114946      114947 2024-12-09 12:32:34+00:00        157583       11154
# 114947      114948 2024-12-09 23:48:29+00:00          4946       11155
# 114948      114949 2024-12-09 23:53:48+00:00        306013       11156
# 114949      114950 2024-12-09 23:54:10+00:00         20979       11157
# 114950      114951 2024-12-09 23:59:15+00:00        306013       11156
#
#         idnt_comienzo  idnt_fin  aleatorio  saltado
# 0                   1         1      False    False
# 1                   2         1      False    False
# 2                   2         1      False    False
# 3                   2         1      False    False
# 4                   2         1      False    False
# ...               ...       ...        ...      ...
# 114946              2         1      False    False
# 114947              4         2      False     True
# 114948              4         1      False    False
# 114949              2         2      False     True
# 114950              4         1      False    False
#
# [114951 rows x 8 columns]

# %% [markdown]
# ### 2.2 Tablas de Podcast
#
# #### 2.2.1 Tablas de Dimensiones
#
# ##### 2.2.1.1 Podcast

# %%
df_show=df_podcast[['Nombre_show_episodio']].drop_duplicates().reset_index(drop=True)
df_show.insert(0,"idnt_show",df_episodios.index+1)
df_show
# Out:
#     idnt_show                               Nombre_show_episodio
# 0           1                                        Wikipodcast
# 1           2                                          Marihuana
# 2           3                                    Nadie Sabe Nada
# 3           4                                     Versos a Voces
# 4           5                               Musicas para Relaxar
# 5           6                     Salud Mental✨ con Alan Disavia
# 6           7             Psicologia Al Desnudo | @psi.mammoliti
# 7           8                              SONIDOS PARA EL ALMA.
# 8           9                               La Pija y la Quinqui
# 9          10                                          Dj bm mix
# 10         11  Meditation Life Skills Podcast - Learn How To ...
# 11         12           Cambia Tu Mente Y Podrás Cambiar Tu Vida
# 12         13                                       Meditaaccion
# 13         14                              LAS MEMORIAS DEL ALMA
# 14         15                                 Sonidos del Cosmos
# 15         16                                        Study Focus
# 16         17                                  Meditation Sounds
# 17         18                              bella’s study corner
# 18         19                                          Dormicast
# 19         20                                Estefania Girón 777
# 20         21                                  Padres Primerizos
# 21         22                             The Sleep Zone Podcast
# 22         23                             Meditación para dormir
# 23         24                                            El Faro
# 24         25                                        BELARRIJANA
# 25         26                      Diario de Alejandra Pizarnik.
# 26         27                                       Conferencias
# 27         28                                  Un Libro Una Hora
# 28         29                                 Tu amiga psicóloga

# %% [markdown]
# ##### 2.2.1.2 Episodio

# %%
df_episodio=df_podcast[['Nombre_episodio','Nombre_show_episodio']].drop_duplicates().reset_index(drop=True)
df_episodio=df_episodio.merge(df_show[['Nombre_show_episodio','idnt_show']],how='left',on='Nombre_show_episodio')
df_episodio=df_episodio[['Nombre_episodio','idnt_show']]
df_episodio.insert(0, 'idnt_episodio', df_episodio.index + 1)
df_episodio
# Out:
#     idnt_episodio                                    Nombre_episodio  \
# 0               1                     Wikipodcast02 - Noticias 07/10
# 1               2                                          marihuana
# 2               3  Nadie Sabe Nada: Que la mascarilla no oculte l...
# 3               4                Como aman los pobres (Gata Cattana)
# 4               5                          Musica para dormir rápido
# ..            ...                                                ...
# 60             61               Desorden mental. 6 de enero de 1968.
# 61             62  Franz Kafka: su vida, su obra, su tiempo (I): ...
# 62             63  Sanación y Milagros Sobrenaturales/ Historias ...
# 63             64  Un libro una hora: El jugador - Fiódor Dostoye...
# 64             65   Las 4 claves para ser emocionalmente inteligente
#
#     idnt_show
# 0           1
# 1           2
# 2           3
# 3           4
# 4           5
# ..        ...
# 60         26
# 61         27
# 62         14
# 63         28
# 64         29
#
# [65 rows x 3 columns]

# %% [markdown]
# #### 2.2.2 Tabla de Hechos
# ##### 2.2.2.1 Podcast

# %%
df_podcasts=df_podcast[['fecha','milisegundos','Nombre_episodio','razon_comienzo','razon_fin','aleatorio','saltado']]

df_podcasts=df_podcasts.merge(df_episodio[['Nombre_episodio','idnt_episodio']],how='left',on='Nombre_episodio')
df_podcasts=df_podcasts.merge(df_comienzo[['razon_comienzo','idnt_comienzo']],how='left',on='razon_comienzo')
df_podcasts=df_podcasts.merge(df_fin[['razon_fin','idnt_fin']],how='left',on='razon_fin')
df_podcasts=df_podcasts[['fecha','milisegundos','idnt_episodio','idnt_comienzo','idnt_fin','aleatorio','saltado']]
df_podcasts
# Out:
#                         fecha  milisegundos  idnt_episodio  idnt_comienzo  \
# 0   2019-01-12 07:31:54+00:00         59360              1              4
# 1   2019-10-19 21:47:19+00:00          3517              2              8
# 2   2020-07-07 13:18:07+00:00             0              3              4
# 3   2020-07-07 13:18:50+00:00         33716              3              4
# 4   2020-07-31 21:48:48+00:00         11717              4              4
# ..                        ...           ...            ...            ...
# 457 2024-10-07 21:49:32+00:00       1686010             43              4
# 458 2024-10-07 21:51:39+00:00          9970             63              2
# 459 2024-10-07 22:46:45+00:00       2703520             43              7
# 460 2024-11-28 20:34:20+00:00          2880             64              4
# 461 2024-12-04 13:06:37+00:00             0             65              9
#
#      idnt_fin  aleatorio  saltado
# 0           2      False    False
# 1           2      False    False
# 2           6      False    False
# 3           2      False    False
# 4           2      False    False
# ..        ...        ...      ...
# 457         2      False     True
# 458         9      False     True
# 459         7      False    False
# 460         2      False     True
# 461         2      False     True
#
# [462 rows x 7 columns]

# %%
df_musica=df_music[['fecha','milisegundos','Nombre_pista','razon_comienzo','razon_fin','aleatorio','saltado']]

df_musica=df_musica.merge(df_cancion[['Nombre_pista','idnt_pista']],how='left',on='Nombre_pista')
df_musica=df_musica.merge(df_comienzo[['razon_comienzo','idnt_comienzo']],how='left',on='razon_comienzo')
df_musica=df_musica.merge(df_fin[['razon_fin','idnt_fin']],how='left',on='razon_fin')

df_musica=df_musica[['fecha','milisegundos','idnt_pista','idnt_comienzo','idnt_fin','aleatorio','saltado']]
df_musica.insert(0, 'idnt_music', df_musica.index + 1)
df_musica

# %% [markdown]
# ## 3. Descarga de tablas

# %%
ruta_fin=path_base+'DATA/REPORTING/'

#Creamos una lista con todas las tablas que queremos descargar
tablas = [
    ("RazonComienzo", df_comienzo),
    ("RazonFin", df_fin),
    ("Artistas", df_artistas),
    ("Albumes", df_album),
    ("Canciones", df_cancion),
    ("Musica", df_musica),
    ("Shows", df_show),
    ("Episodios", df_episodio),
    ("Podcasts", df_podcasts)
]

#Función general para guardar los DataFrames en archivos CSV
def guardar_tabla(tabla, ruta):
    for nombre, df in tabla:
        df.to_csv(os.path.join(ruta, f"{nombre}.csv"), index=False)

guardar_tabla(tablas, ruta_fin)

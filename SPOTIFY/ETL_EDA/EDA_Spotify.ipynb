# %% [markdown]
# # EDA SPOTIFY DATA

# %%
#Librerias
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import math
from datetime import datetime as dt, timedelta
import warnings

#Ignoramos todos los warnings
warnings.filterwarnings('ignore')

# %%
def descripcion(df):
    tipos = df.dtypes
    nulos = df.isnull().sum()
    unicos = df.nunique()
    duplicados = df.duplicated().sum(axis=0)
    valores = df.count()

    df_result = pd.DataFrame({
        'Columna': df.columns,
        'Tipo': tipos,
        'Valores': valores,
        'Nulos': nulos,
        'Unicos': unicos,
        'Duplicados': duplicados
    })
    
    return df_result

# %% [markdown]
# ## 1. Carga de datos

# %%
path_base='/Users/Garazi/Desktop/SPOTIFY/DATA/ORIGEN/'
archivo_1='Streaming_History_Audio_2016_2019_0.json'
archivo_2='Streaming_History_Audio_2019_2020_1.json'
archivo_3='Streaming_History_Audio_2020_2021_2.json'
archivo_4='Streaming_History_Audio_2021_2023_3.json'
archivo_5='Streaming_History_Audio_2023_2024_4.json'


df_1619=pd.read_json(path_base+archivo_1)
df_1920=pd.read_json(path_base+archivo_2)
df_2021=pd.read_json(path_base+archivo_3)
df_2123=pd.read_json(path_base+archivo_4)
df_2324=pd.read_json(path_base+archivo_5)

# %%
#Se juntas los datos de todos los años en un único df y eliminamos los duplicados que hemos generado
df=pd.concat([df_1619,df_1920,df_2021,df_2123,df_2324])
df.drop_duplicates(inplace=True)

descripcion(df)
# Out:
#                                                              Columna     Tipo  \
# ts                                                                ts   object
# platform                                                    platform   object
# ms_played                                                  ms_played    int64
# conn_country                                            conn_country   object
# ip_addr                                                      ip_addr   object
# master_metadata_track_name                master_metadata_track_name   object
# master_metadata_album_artist_name  master_metadata_album_artist_name   object
# master_metadata_album_album_name    master_metadata_album_album_name   object
# spotify_track_uri                                  spotify_track_uri   object
# episode_name                                            episode_name   object
# episode_show_name                                  episode_show_name   object
# spotify_episode_uri                              spotify_episode_uri   object
# reason_start                                            reason_start   object
# reason_end                                                reason_end   object
# shuffle                                                      shuffle     bool
# skipped                                                      skipped     bool
# offline                                                      offline     bool
# offline_timestamp                                  offline_timestamp  float64
# incognito_mode                                        incognito_mode     bool
#
#                                    Valores  Nulos  Unicos  Duplicados
# ts                                   89474      0   88261           0
# platform                             89474      0      29           0
# ms_played                            89474      0   32342           0
# conn_country                         89474      0       4           0
# ip_addr                              89474      0    2973           0
# master_metadata_track_name           89012    462   10273           0
# master_metadata_album_artist_name    89012    462    1999           0
# master_metadata_album_album_name     89012    462    5200           0
# spotify_track_uri                    89012    462   11735           0
# episode_name                           462  89012      65           0
# episode_show_name                      462  89012      29           0
# spotify_episode_uri                    462  89012      65           0
# reason_start                         89474      0       9           0
# reason_end                           89474      0      11           0
# shuffle                              89474      0       2           0
# skipped                              89474      0       2           0
# offline                              89474      0       2           0
# offline_timestamp                    22002  67472   21927           0
# incognito_mode                       89474      0       2           0

# %%
#La columna ts (fecha) es de tipo object, la ponemos como datetime
df['ts'] = pd.to_datetime(df['ts'])
df['ts'].dtype
# Out:
# datetime64[ns, UTC]

# %% [markdown]
# ## 2. Análisis general

# %% [markdown]
# Significado de todas las variables:

# %%
df_columnas=pd.DataFrame()
data = {
    "Campo técnico": [
        "ts", "username", "platform", "ms_played", "conn_country", "Ip_addr_decrypted",
        "user_agent_decrypted", "master_metadata_track_name", "master_metadata_album_artist_name",
        "master_metadata_album_album_name", "spotify_track_uri", "episode_name",
        "episode_show_name", "spotify_episode_uri", "reason_start", "reason_end",
        "shuffle", "skipped", "offline", "offline_timestamp", "incognito_mode"
    ],
    "Contenido": [
        "Marca de tiempo que indica cuándo se dejó de reproducir una canción en formato UTC (Tiempo Universal Coordinado). El orden de la fecha es año, mes y día, seguida por una marca de tiempo en formato de 24 horas.",
        "nombre de usuario o usuaria de Spotify.",
        "la plataforma que se usó al escuchar la canción ",
        "número de milisegundos que duró la reproducción.",
        "el código de país para especificar dónde se escuchó la canción",
        "dirección IP registrada",
        "el agente de usuario que se usó al reproducir la canción ",
        "nombre de la pista.",
        "el nombre del artista o la artista, del grupo o del podcast.",
        "el nombre del álbum que incluye la canción.",
        "Un URI de Spotify que identifica de forma única la canción",
        "el nombre del episodio del podcast.",
        "el nombre del programa del podcast.",
        "Un URI de episodio de Spotify que identifica de forma única el episodio de podcast.",
        "valor que indica por qué se empezó a reproducir la canción ",
        "por qué se acabó de reproducir la canción (por ejemplo, “endplay”).",
        " tiene el valor \"True\" o \"False\" según si se usó o no el modo aleatorio al escuchar la canción.",
        "si los usuarios se saltaron la canción.",
        " si la canción se escuchó en el modo sin conexión (“True”) o no (“False”).",
        " una marca de tiempo de cuándo se usó el modo sin conexión, si es que se usó.",
        "si la canción se escuchó durante una sesión privada (“True”) o no (“False”)."
    ]
}

df_columnas=pd.DataFrame(data)

df_columnas
# Out:
#                         Campo técnico  \
# 0                                  ts
# 1                            username
# 2                            platform
# 3                           ms_played
# 4                        conn_country
# 5                   Ip_addr_decrypted
# 6                user_agent_decrypted
# 7          master_metadata_track_name
# 8   master_metadata_album_artist_name
# 9    master_metadata_album_album_name
# 10                  spotify_track_uri
# 11                       episode_name
# 12                  episode_show_name
# 13                spotify_episode_uri
# 14                       reason_start
# 15                         reason_end
# 16                            shuffle
# 17                            skipped
# 18                            offline
# 19                  offline_timestamp
# 20                     incognito_mode
#
#                                             Contenido
# 0   Marca de tiempo que indica cuándo se dejó de r...
# 1             nombre de usuario o usuaria de Spotify.
# 2    la plataforma que se usó al escuchar la canción
# 3    número de milisegundos que duró la reproducción.
# 4   el código de país para especificar dónde se es...
# 5                             dirección IP registrada
# 6   el agente de usuario que se usó al reproducir ...
# 7                                 nombre de la pista.
# 8   el nombre del artista o la artista, del grupo ...
# 9         el nombre del álbum que incluye la canción.
# 10  Un URI de Spotify que identifica de forma únic...
# 11                el nombre del episodio del podcast.
# 12                el nombre del programa del podcast.
# 13  Un URI de episodio de Spotify que identifica d...
# 14  valor que indica por qué se empezó a reproduci...
# 15  por qué se acabó de reproducir la canción (por...
# 16   tiene el valor "True" o "False" según si se u...
# 17            si los usuarios se saltaron la canción.
# 18   si la canción se escuchó en el modo sin conex...
# 19   una marca de tiempo de cuándo se usó el modo ...
# 20  si la canción se escuchó durante una sesión pr...

# %% [markdown]
# Seleccionamos variables de interes y las renombramos:

# %%
df.columns
# Out:
# Index(['ts', 'platform', 'ms_played', 'conn_country', 'ip_addr',
#        'master_metadata_track_name', 'master_metadata_album_artist_name',
#        'master_metadata_album_album_name', 'spotify_track_uri', 'episode_name',
#        'episode_show_name', 'spotify_episode_uri', 'reason_start',
#        'reason_end', 'shuffle', 'skipped', 'offline', 'offline_timestamp',
#        'incognito_mode'],
#       dtype='object')

# %%
df=df[['ts','ms_played','master_metadata_track_name', 'master_metadata_album_artist_name',
       'master_metadata_album_album_name', 'episode_name','episode_show_name', 'reason_start',
       'reason_end', 'shuffle', 'skipped']]

df.rename(columns=({'ts':'fecha','ms_played':'milisegundos',
                   'master_metadata_track_name':'Nombre_pista',
                   'master_metadata_album_artist_name':'Nombre_artista',
                   'master_metadata_album_album_name':'Nombre_album',
                   'episode_name':'Nombre_episodio',
                   'episode_show_name':'Nombre_show_episodio',
                   'reason_start':'razon_comienzo',
                   'reason_end':'razon_fin',
                   'shuffle':'aleatorio',
                   'skipped':'saltado'}), inplace=True)

df.head()
# Out:
#                       fecha  milisegundos Nombre_pista Nombre_artista  \
# 0 2016-02-09 13:44:41+00:00        333659        Sorry  Justin Bieber
# 1 2016-02-09 13:48:02+00:00        200786        Sorry  Justin Bieber
# 2 2016-02-09 13:51:23+00:00        200786        Sorry  Justin Bieber
# 3 2016-02-09 13:54:44+00:00        200786        Sorry  Justin Bieber
# 4 2016-02-09 13:58:41+00:00        200786        Sorry  Justin Bieber
#
#   Nombre_album Nombre_episodio Nombre_show_episodio razon_comienzo  razon_fin  \
# 0      Purpose            None                 None        appload  trackdone
# 1      Purpose            None                 None      trackdone  trackdone
# 2      Purpose            None                 None      trackdone  trackdone
# 3      Purpose            None                 None      trackdone  trackdone
# 4      Purpose            None                 None      trackdone  trackdone
#
#    aleatorio  saltado
# 0      False    False
# 1      False    False
# 2      False    False
# 3      False    False
# 4      False    False

# %% [markdown]
# Partiendo del df general creamos dos dfs diferentes: uno con datos de podcasts/epidodios (df_podcast), y otro con datos de canciones (df_music). Y eliminamos de cada df las columnas que no tienen que ver con su contenido (estas columnas aparecen rellenas con Nan/None).

# %%
df_podcast=df[df['Nombre_show_episodio'].notna()]
df_podcast.dropna(axis=1, how='all', inplace=True)
df_music=df[~df['Nombre_show_episodio'].notna()]
df_music.dropna(axis=1, how='all', inplace=True)

# %% [markdown]
# ### 2.1 Canciones

# %%
df_music.head()
# Out:
#                       fecha  milisegundos Nombre_pista Nombre_artista  \
# 0 2016-02-09 13:44:41+00:00        333659        Sorry  Justin Bieber
# 1 2016-02-09 13:48:02+00:00        200786        Sorry  Justin Bieber
# 2 2016-02-09 13:51:23+00:00        200786        Sorry  Justin Bieber
# 3 2016-02-09 13:54:44+00:00        200786        Sorry  Justin Bieber
# 4 2016-02-09 13:58:41+00:00        200786        Sorry  Justin Bieber
#
#   Nombre_album razon_comienzo  razon_fin  aleatorio  saltado
# 0      Purpose        appload  trackdone      False    False
# 1      Purpose      trackdone  trackdone      False    False
# 2      Purpose      trackdone  trackdone      False    False
# 3      Purpose      trackdone  trackdone      False    False
# 4      Purpose      trackdone  trackdone      False    False

# %%
df_music.shape
# Out:
# (89012, 9)

# %%
descripcion(df_music)
# Out:
#                        Columna                 Tipo  Valores  Nulos  Unicos  \
# fecha                    fecha  datetime64[ns, UTC]    89012      0   87803
# milisegundos      milisegundos                int64    89012      0   32067
# Nombre_pista      Nombre_pista               object    89012      0   10273
# Nombre_artista  Nombre_artista               object    89012      0    1999
# Nombre_album      Nombre_album               object    89012      0    5200
# razon_comienzo  razon_comienzo               object    89012      0       9
# razon_fin            razon_fin               object    89012      0      11
# aleatorio            aleatorio                 bool    89012      0       2
# saltado                saltado                 bool    89012      0       2
#
#                 Duplicados
# fecha                   21
# milisegundos            21
# Nombre_pista            21
# Nombre_artista          21
# Nombre_album            21
# razon_comienzo          21
# razon_fin               21
# aleatorio               21
# saltado                 21

# %% [markdown]
# Razones de comienzo y final de las canciones:

# %%
df_music['razon_comienzo'].value_counts()
# Out:
# trackdone     58464
# fwdbtn        12081
# clickrow      10065
# appload        4191
# playbtn        2413
# backbtn        1391
# remote          258
# trackerror       81
# unknown          68
# Name: razon_comienzo, dtype: int64

# %%
df_music['razon_fin'].value_counts()
# Out:
# trackdone                       57622
# fwdbtn                          12081
# endplay                         10242
# logout                           4219
# unexpected-exit-while-paused     2643
# backbtn                          1345
# unexpected-exit                   585
# unknown                           133
# remote                            132
# appload                             8
# trackerror                          2
# Name: razon_fin, dtype: int64

# %% [markdown]
# Estadísticas de canciones reproducidas en modo aleatroio y canciones saltadas:

# %%
total=df_music.shape[0]
aleatorio= len(df_music[df_music['aleatorio']==True])
no_aleatorio= len(df_music[df_music['aleatorio']==False])

print(f'Número de canciones reproducidas en modo aleatorio: {aleatorio} ({round(100*aleatorio/total,2)} %)')
print(f'Número de canciones reproducidas en modo NO aleatorio: {no_aleatorio} ({round(100*no_aleatorio/total,2)} %)')
# Out:
# Número de canciones reproducidas en modo aleatorio: 39128 (43.96 %)
# Número de canciones reproducidas en modo NO aleatorio: 49884 (56.04 %)

# %%
total=df_music.shape[0]
saltado= len(df_music[df_music['saltado']==True])
no_saltado= len(df_music[df_music['saltado']==False])

print(f'El {round(100*saltado/total,2)} % de las canciones han sido saltadas antes de terminar la pista completa')
# Out:
# El 6.14 % de las canciones han sido saltadas antes de terminar la pista completa

# %% [markdown]
# #### 2.1.1 Artistas y canciones más escuchadas

# %%
df_music.head(2)
# Out:
#                       fecha  milisegundos Nombre_pista Nombre_artista  \
# 0 2016-02-09 13:44:41+00:00        333659        Sorry  Justin Bieber
# 1 2016-02-09 13:48:02+00:00        200786        Sorry  Justin Bieber
#
#   Nombre_album razon_comienzo  razon_fin  aleatorio  saltado
# 0      Purpose        appload  trackdone      False    False
# 1      Purpose      trackdone  trackdone      False    False

# %%
df_music[(df_music['fecha'].dt.year==2022) & (df_music['saltado']==False)]['Nombre_artista'].value_counts().head(15)
# Out:
# Natos y Waor    745
# Bad Bunny       488
# Bad Gyal        442
# ROSALÍA         434
# LUNA KI         385
# John Pollõn     315
# Hofe            309
# K1ZA            303
# Gata Cattana    278
# Chill Chicos    275
# Cariño          256
# GARRAIO         234
# Dellachaouen    231
# Melendi         221
# Amaia           176
# Name: Nombre_artista, dtype: int64

# %%
df_music['Nombre_pista'].value_counts()
# Out:
# Gremlin                                      213
# Hustlers                                     186
# Si Veo a Tu Mamá                             183
# Cicatrices                                   177
# Septiembre                                   170
#                                             ...
# De Cacería                                     1
# Digan Lo Que Quieran                           1
# Hablando de Nada                               1
# La Habitación Que Más Me Gusta de Mi Keli      1
# Ondas Delta para Relajarse                     1
# Name: Nombre_pista, Length: 10273, dtype: int64

# %% [markdown]
# ### 2.2 Podcasts

# %%
df_podcast
# Out:
#                           fecha  milisegundos  \
# 15968 2019-01-12 07:31:54+00:00         59360
# 6938  2019-10-19 21:47:19+00:00          3517
# 5421  2020-07-07 13:18:07+00:00             0
# 5422  2020-07-07 13:18:50+00:00         33716
# 6033  2020-07-31 21:48:48+00:00         11717
# ...                         ...           ...
# 14159 2024-10-07 21:49:32+00:00       1686010
# 14160 2024-10-07 21:51:39+00:00          9970
# 14161 2024-10-07 22:46:45+00:00       2703520
# 15480 2024-11-28 20:34:20+00:00          2880
# 15711 2024-12-04 13:06:37+00:00             0
#
#                                          Nombre_episodio  \
# 15968                     Wikipodcast02 - Noticias 07/10
# 6938                                           marihuana
# 5421   Nadie Sabe Nada: Que la mascarilla no oculte l...
# 5422   Nadie Sabe Nada: Que la mascarilla no oculte l...
# 6033                 Como aman los pobres (Gata Cattana)
# ...                                                  ...
# 14159         Sueño Profundo y Reparación Con Antiestrés
# 14160  Sanación y Milagros Sobrenaturales/ Historias ...
# 14161         Sueño Profundo y Reparación Con Antiestrés
# 15480  Un libro una hora: El jugador - Fiódor Dostoye...
# 15711   Las 4 claves para ser emocionalmente inteligente
#
#         Nombre_show_episodio razon_comienzo        razon_fin  aleatorio  \
# 15968            Wikipodcast       clickrow          endplay      False
# 6938               Marihuana        playbtn          endplay      False
# 5421         Nadie Sabe Nada       clickrow  unexpected-exit      False
# 5422         Nadie Sabe Nada       clickrow          endplay      False
# 6033          Versos a Voces       clickrow          endplay      False
# ...                      ...            ...              ...        ...
# 14159  LAS MEMORIAS DEL ALMA       clickrow          endplay      False
# 14160  LAS MEMORIAS DEL ALMA      trackdone          backbtn      False
# 14161  LAS MEMORIAS DEL ALMA        backbtn           logout      False
# 15480      Un Libro Una Hora       clickrow          endplay      False
# 15711     Tu amiga psicóloga        unknown          endplay      False
#
#        saltado
# 15968    False
# 6938     False
# 5421     False
# 5422     False
# 6033     False
# ...        ...
# 14159     True
# 14160     True
# 14161    False
# 15480     True
# 15711     True
#
# [462 rows x 8 columns]

# %%
df['Nombre_show_episodio'].value_counts()
# Out:
# Musicas para Relaxar                                      239
# La Pija y la Quinqui                                       76
# Dj bm mix                                                  58
# LAS MEMORIAS DEL ALMA                                      22
# Salud Mental✨ con Alan Disavia                              9
# Meditation Life Skills Podcast - Learn How To Meditate      8
# Cambia Tu Mente Y Podrás Cambiar Tu Vida                    6
# Sonidos del Cosmos                                          5
# SONIDOS PARA EL ALMA.                                       4
# Psicologia Al Desnudo | @psi.mammoliti                      4
# Study Focus                                                 4
# Meditation Sounds                                           4
# Meditaaccion                                                3
# Nadie Sabe Nada                                             2
# Dormicast                                                   2
#  Estefania Girón 777                                        2
# El Faro                                                     2
# Un Libro Una Hora                                           1
# Meditación para dormir                                      1
# Conferencias                                                1
# Diario de Alejandra Pizarnik.                               1
# BELARRIJANA                                                 1
# Wikipodcast                                                 1
# The Sleep Zone Podcast                                      1
# Padres Primerizos                                           1
# bella’s study corner                                        1
# Marihuana                                                   1
# Versos a Voces                                              1
# Tu amiga psicóloga                                          1
# Name: Nombre_show_episodio, dtype: int64
